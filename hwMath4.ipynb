# %% [markdown]
# #  Ex. 1 Part B

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Our data
advertising_investment = np.array([10, 15, 20, 25, 30, 35, 40, 45, 50]).reshape(-1, 1)  
sales_growth = np.array([25, 30, 40, 45, 50, 60, 65, 70, 80]) 
# Create regression model
model = LinearRegression()
model.fit(advertising_investment, sales_growth)

# Print results
print(f"Slope (m): {model.coef_[0]:.2f}")
print(f"Intercept (b): {model.intercept_:.2f}")

# Calculate equation
equation = f"y = {model.coef_[0]:.2f}x + {model.intercept_:.2f}"
print(f"Line equation: {equation}")

# Predict sales needed to get profit of 100
profit_to_predict = 100
ads_needed = (profit_to_predict - model.intercept_) / model.coef_[0]
print(f"To get a sales of 100 profit, approximately {ads_needed:.2f} ads investment are needed")

# Create the graph
plt.figure(figsize=(10, 6))
plt.scatter(advertising_investment, sales_growth, color='blue', label='Data points')
plt.plot(advertising_investment, model.predict(advertising_investment), color='red', label='Regression line')

# Add prediction point
plt.scatter([[ads_needed]], [100], color='green', s=100, label='Our prediction')

# Add labels in English
plt.title('Linear Regression - Advertising vs. Sales')
plt.xlabel('Advertising Investment')
plt.ylabel('Sales')
plt.grid(True)
plt.legend(loc='center right')

# Display equation on the graph
plt.text(1, 0, equation, fontsize=12)

plt.show()
# Out:
# Slope (m): 1.35
# Intercept (b): 11.17
# Line equation: y = 1.35x + 11.17
# To get a sales of 100 profit, approximately 65.80 ads investment are needed

# %% [markdown]
# # Ex. 1 part D

# %%
x = [10, 15, 20, 25, 30, 35, 40, 45, 50]
y = [25, 30, 40, 45, 50, 60, 65, 70, 80]

coeffs = np.polyfit(x, y, deg=1)
slope = coeffs[0]
intercept = coeffs[1]
print(f"y = {slope:.2f}x + {intercept:.2f}")
# Out:
# y = 1.35x + 11.17

# %% [markdown]
# # Ex. 2 Part D

# %%
# Our data
calls = np.array([2,3,4,5,6]).reshape(-1, 1)  
sales = np.array([50, 70, 90, 100, 110])

# Create regression model
model = LinearRegression()
model.fit(calls, sales)

# Print results
print(f"Slope (m): {model.coef_[0]:.2f}")
print(f"Intercept (b): {model.intercept_:.2f}")

# Calculate equation
equation = f"y = {model.coef_[0]:.2f}x + {model.intercept_:.2f}"
print(f"Line equation: {equation}")

# Predict sales needed to get profit of 150
profit_to_predict = 150
calls_needed = (profit_to_predict - model.intercept_) / model.coef_[0]
print(f"To get a sales of 110 profit, approximately {calls_needed:.2f} calls hours are needed")

# Create the graph
plt.figure(figsize=(10, 6))
plt.scatter(calls, sales, color='blue', label='Data points')
plt.plot(calls, model.predict(calls), color='red', label='Regression line')

# Add prediction point
plt.scatter([[calls_needed]], [150], color='green', s=100, label='Our prediction')

# Add labels in English
plt.title('Linear Regression - Calls Hours vs. Sales')
plt.xlabel('Calls Hours')
plt.ylabel('Sales')
plt.grid(True)
plt.legend(loc='center right')

# Display equation on the graph
plt.text(1, 0, equation, fontsize=12)

plt.show()
# Out:
# Slope (m): 15.00
# Intercept (b): 24.00
# Line equation: y = 15.00x + 24.00
# To get a sales of 110 profit, approximately 8.40 calls hours are needed

# %%
# Our data
calls = np.array([2,3,4,5,6]).reshape(-1, 1)  
sales = np.array([50, 70, 90, 100, 110])

# Create regression model
model = LinearRegression()
model.fit(calls, sales)

# Print results
print(f"Slope (m): {model.coef_[0]:.2f}")
print(f"Intercept (b): {model.intercept_:.2f}")

# Calculate equation
equation = f"y = {model.coef_[0]:.2f}x + {model.intercept_:.2f}"
print(f"Line equation: {equation}")

# Predict sales needed to get profit of 350
profit_to_predict = 350
calls_needed = (profit_to_predict - model.intercept_) / model.coef_[0]
print(f"To get a sales of 110 profit, approximately {calls_needed:.2f} calls hours are needed")

# Create smooth range from 6 to 20
x_range = np.linspace(6, 20, 100).reshape(-1, 1)
y_range = model.predict(x_range)

# Create the graph
plt.figure(figsize=(10, 6))
plt.scatter(calls, sales, color='blue', label='Data points')
plt.plot(x_range, y_range, color='red', label='Regression line')

# Add prediction point
plt.scatter([[calls_needed]], [350], color='green', s=100, label='Our prediction')

# Add labels in English
plt.title('Linear Regression - Calls Hours vs. Sales')
plt.xlabel('Calls Hours')
plt.ylabel('Sales')
plt.grid(True)
plt.legend(loc='center right')

# Display equation on the graph
plt.text(1, 0, equation, fontsize=12)

plt.show()
# Out:
# Slope (m): 15.00
# Intercept (b): 24.00
# Line equation: y = 15.00x + 24.00
# To get a sales of 110 profit, approximately 21.73 calls hours are needed

# %%
import pandas as pd
import seaborn as sns
import scipy.stats

df = pd.DataFrame({
    'calls': [2, 3, 4, 5, 6],
    'sales': [50, 70, 90, 100, 110]
})


plot = sns.regplot(data=df, x='calls', y='sales', ci=None, color='blue')

slope, intercept, r, p_value, stderr = scipy.stats.linregress(
    x=plot.get_lines()[0].get_xdata(),
    y=plot.get_lines()[0].get_ydata()
)

# Predict sales for 8.4 call hours (e.g., based on previous calc)
prediction_x = 8.4
slope, intercept, r, p_value, stderr = scipy.stats.linregress(df['calls'], df['sales'])
prediction_y = slope * prediction_x + intercept

# Add prediction point
plt.scatter(prediction_x, prediction_y, color='green', s=100, label='Prediction (8.4 hrs)')

equation = f"y = {slope:.2f}x + {intercept:.2f}"
print(f"Regression line: {equation}")

plt.text(1,0, equation, fontsize=12)

plt.title('Call Hours vs. Sales')
plt.xlabel('Calls Hours per Day')
plt.ylabel('Sales (10K$)')
plt.grid(True)
plt.legend(loc='lower right')

plt.show()
# Out:
# Regression line: y = 15.00x + 24.00
